# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV

# %%
# Baca dataset
df = pd.read_excel('dataset_clean_2018-2023.xlsx')

# %%
# Konversi kolom 'Harga' menjadi numerik
df['Harga'] = pd.to_numeric(df['Harga'], errors='coerce').astype('int64')

# %%
# Skala data
scaler = MinMaxScaler(feature_range=(0, 1))
df['Harga_scaled'] = scaler.fit_transform(df['Harga'].values.reshape(-1, 1))

# %%
# Buat urutan data untuk Random Forest
def create_sequences(data, seq_length):
    x, y = [], []
    for i in range(len(data) - seq_length):
        x.append(data[i:i + seq_length])
        y.append(data[i + seq_length])
    return np.array(x), np.array(y)

# %%
# Parameter
seq_length = 2  # Panjang urutan

# %%
# Definisikan parameter grid
param_grid = {
    'n_estimators': [100, 200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 10, 20],
    'min_samples_leaf': [1, 5, 10],
    'bootstrap': [True, False]
}

# %%
# Dictionary untuk menyimpan model, scaler, data uji, dan feature importances tiap provinsi
models_rf = {}
scalers_rf = {}
test_data_dict = {}
feature_importances_dict = {}

# %%
# Loop untuk melatih model tiap provinsi dengan Grid Search
for provinsi in df['Nama Provinsi'].unique():
    provinsi_data = df[df['Nama Provinsi'] == provinsi]['Harga_scaled'].values
    
    if len(provinsi_data) < seq_length + 1:
        print(f"Skipping {provinsi} due to insufficient data.")
        continue
    
    # Buat urutan data untuk Random Forest
    x, y = create_sequences(provinsi_data, seq_length)
    
    # Pisahkan data menjadi set pelatihan dan pengujian
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, shuffle=False)
    
    # Inisialisasi model Random Forest
    model_rf = RandomForestRegressor(random_state=42)
    
    # Inisialisasi Grid Search
    grid_search = GridSearchCV(estimator=model_rf, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
    
    # Fit Grid Search ke data
    grid_search.fit(x_train, y_train)
    
    # Simpan model terbaik dan parameter
    best_model_rf = grid_search.best_estimator_
    models_rf[provinsi] = best_model_rf
    scalers_rf[provinsi] = scaler
    
    # Simpan data uji dan feature importances
    test_data_dict[provinsi] = y_test
    feature_importances_dict[provinsi] = best_model_rf.feature_importances_
    
    print(f"Model for {provinsi} trained with best parameters: {grid_search.best_params_}")

print("Model training completed.")
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Aceh trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Bali trained with best parameters: {'bootstrap': True, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Banten trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Bengkulu trained with best parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for DI Yogyakarta trained with best parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for DKI Jakarta trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Gorontalo trained with best parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Jambi trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Jawa Barat trained with best parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 500}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Jawa Tengah trained with best parameters: {'bootstrap': True, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Jawa Timur trained with best parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Kalimantan Barat trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 200}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Kalimantan Selatan trained with best parameters: {'bootstrap': True, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Kalimantan Tengah trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 500}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Kalimantan Timur trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 200}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Kalimantan Utara trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Kepulauan Riau trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 200}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Lampung trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Maluku trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Maluku Utara trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Nusa Tenggara Barat trained with best parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Nusa Tenggara Timur trained with best parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Papua trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 500}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Riau trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 200}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Sulawesi Barat trained with best parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 200}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Sulawesi Selatan trained with best parameters: {'bootstrap': True, 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Sulawesi Tenggara trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Sulawesi Utara trained with best parameters: {'bootstrap': True, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Sumatera Barat trained with best parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 500}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Sumatera Selatan trained with best parameters: {'bootstrap': True, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Sumatera Utara trained with best parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Kepulauan Bangka Belitung trained with best parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 500}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Sulawesi Tengah trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 200}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for Papua Barat trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Model for D.I Yogyakarta trained with best parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Model training completed.

# %%
# Fungsi untuk menampilkan data uji
def show_test_data(provinsi):
    if provinsi in test_data_dict:
        print(f"Test data for {provinsi}:")
        print(test_data_dict[provinsi])
    else:
        print(f"No test data found for {provinsi}.")

# %%
# Contoh penggunaan fungsi untuk menampilkan data uji provinsi tertentu
show_test_data('Sumatera Barat')
show_test_data('Bali')
# Out:
# Test data for Sumatera Barat:
# [0.85146399 0.83436632 0.83276341 0.83222911 0.83436632 0.82314597
#  0.83810643 0.88886514 0.88993375 0.87497328 0.88619363 0.90435991
#  0.92573199 0.92840351 0.91397735]
# Test data for Bali:
# [0.70079077 0.71147681 0.71147681 0.71147681 0.70239367 0.70559949
#  0.74727506 0.78841633 0.80070528 0.79375935 0.79482795 0.81833725
#  0.89634537 0.86215003 0.8311605 ]

# %%
# Fungsi untuk memplot feature importances untuk satu provinsi
def plot_feature_importances(provinsi):
    if provinsi in feature_importances_dict:
        importances = feature_importances_dict[provinsi]
        plt.figure()
        plt.bar(range(len(importances)), importances, label=f"{provinsi} Feature Importances")
        plt.title(f"Feature Importances for {provinsi}")
        plt.xlabel("Feature Index")
        plt.ylabel("Importance")
        plt.legend()
        plt.show()
    else:
        print(f"No feature importances found for {provinsi}.")

# %%
# Contoh penggunaan fungsi untuk memplot feature importances untuk provinsi tertentu
plot_feature_importances('Bali')

# %%
# Plot feature importances untuk setiap provinsi
plt.figure(figsize=(15, 10))
for provinsi, importances in feature_importances_dict.items():
    plt.bar(range(len(importances)), importances, alpha=0.5, label=f"{provinsi} Feature Importances")

plt.title("Feature Importances per Provinsi")
plt.xlabel("Feature Index")
plt.ylabel("Importance")
plt.legend()
plt.show()

# %%
# Fungsi untuk menghitung metrik evaluasi
def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = mean_absolute_percentage_error(y_true, y_pred) * 100
    r2 = r2_score(y_true, y_pred)
    return rmse, mape, r2

# %%
# Dictionary untuk menyimpan metrik evaluasi tiap provinsi
metrics_rf_dict = {}

# %%
# Loop untuk menghitung metrik evaluasi tiap provinsi
for provinsi in df['Nama Provinsi'].unique():
    if provinsi not in models_rf:
        print(f"No model found for {provinsi}. Skipping evaluation.")
        continue
    
    # Ambil model dan scaler untuk provinsi ini
    model_rf = models_rf[provinsi]
    scaler = scalers_rf[provinsi]
    
    # Ambil data uji
    provinsi_data = df[df['Nama Provinsi'] == provinsi]['Harga_scaled'].values
    x, y = create_sequences(provinsi_data, seq_length)
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, shuffle=False)
    
    # Prediksi nilai
    y_pred = model_rf.predict(x_test)
    
    # Balikkan skala nilai prediksi dan nilai sebenarnya
    y_test = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()
    y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1)).flatten()
    
    # Hitung metrik evaluasi
    rmse, mape, r2 = calculate_metrics(y_test, y_pred)
    metrics_rf_dict[provinsi] = {'RMSE': rmse, 'MAPE': mape, 'R-Squared': r2, 'y_true': y_test, 'y_pred': y_pred}
    
    print(f"Metrics for {provinsi}: RMSE = {rmse}, MAPE = {mape}%, R-Squared = {r2}")
# Out:
# Metrics for Aceh: RMSE = 1353.1127457204877, MAPE = 7.490101191658409%, R-Squared = -1.443208117851385
# Metrics for Bali: RMSE = 2362.0397791696873, MAPE = 13.44884824598585%, R-Squared = -3.1732729534533632
# Metrics for Banten: RMSE = 1901.2934802623843, MAPE = 9.557166313668665%, R-Squared = -1.046784915662737
# Metrics for Bengkulu: RMSE = 1914.9314892267814, MAPE = 9.777981271704355%, R-Squared = -1.5371550574712023
# Metrics for DI Yogyakarta: RMSE = 210.63221211721464, MAPE = 1.2688408467004628%, R-Squared = 0.35708980639914534
# Metrics for DKI Jakarta: RMSE = 2134.1178668786965, MAPE = 9.892052818051699%, R-Squared = -0.7019596192828581
# Metrics for Gorontalo: RMSE = 3267.5660644829613, MAPE = 18.501344208455897%, R-Squared = -3.6457919583198617
# Metrics for Jambi: RMSE = 1821.7037842877712, MAPE = 10.396840222402846%, R-Squared = -2.5743947182024534
# Metrics for Jawa Barat: RMSE = 1880.8316316637577, MAPE = 9.062213907302016%, R-Squared = -1.0854872210334272
# Metrics for Jawa Tengah: RMSE = 1980.493121005067, MAPE = 9.736459942348983%, R-Squared = -2.1084655418390374
# Metrics for Jawa Timur: RMSE = 1481.8668617096928, MAPE = 7.472411839168148%, R-Squared = -1.134064294641214
# Metrics for Kalimantan Barat: RMSE = 2022.1800097526932, MAPE = 10.908715979631598%, R-Squared = -3.4401067190144374
# Metrics for Kalimantan Selatan: RMSE = 761.2076310531972, MAPE = 3.6704377815469265%, R-Squared = 0.3532574514419027
# Metrics for Kalimantan Tengah: RMSE = 1310.834480659586, MAPE = 6.1790354258233045%, R-Squared = -1.7267356931428601
# Metrics for Kalimantan Timur: RMSE = 2649.974989592698, MAPE = 14.953958062104602%, R-Squared = -5.955979576389753
# Metrics for Kalimantan Utara: RMSE = 2039.7862780470955, MAPE = 11.586869441920266%, R-Squared = -6.54997607596217
# Metrics for Kepulauan Riau: RMSE = 1022.8811711692506, MAPE = 5.462911537568971%, R-Squared = -0.6279639056919235
# Metrics for Lampung: RMSE = 1937.0302384903498, MAPE = 9.79591232122803%, R-Squared = -1.65173927293958
# Metrics for Maluku: RMSE = 1974.8906185514747, MAPE = 10.43530297867998%, R-Squared = -3.5869896667401466
# Metrics for Maluku Utara: RMSE = 2544.8024819156344, MAPE = 14.074918418720403%, R-Squared = -6.390076939499508
# Metrics for Nusa Tenggara Barat: RMSE = 2354.6400781524057, MAPE = 11.325162496525799%, R-Squared = -1.1996366724114416
# Metrics for Nusa Tenggara Timur: RMSE = 2728.1111928687114, MAPE = 15.868244666148243%, R-Squared = -4.683692473145915
# Metrics for Papua: RMSE = 2185.607716829321, MAPE = 10.65227380972502%, R-Squared = -2.8679839438435057
# Metrics for Riau: RMSE = 1501.7765953526036, MAPE = 7.562344937631367%, R-Squared = -0.7772994291363438
# Metrics for Sulawesi Barat: RMSE = 1769.1986730259591, MAPE = 9.813854827827472%, R-Squared = -1.7702339478922786
# Metrics for Sulawesi Selatan: RMSE = 2022.5298263445495, MAPE = 10.524276860691364%, R-Squared = -2.6969434935411134
# Metrics for Sulawesi Tenggara: RMSE = 1889.5986011584484, MAPE = 10.80218287396106%, R-Squared = -2.297140058021392
# Metrics for Sulawesi Utara: RMSE = 2041.5463687868273, MAPE = 12.009374738114802%, R-Squared = -3.526896478614826
# Metrics for Sumatera Barat: RMSE = 2090.8367344198564, MAPE = 11.98193417602831%, R-Squared = -8.563014617093138
# Metrics for Sumatera Selatan: RMSE = 1690.3848422928252, MAPE = 8.991771804037343%, R-Squared = -2.5126104918357988
# Metrics for Sumatera Utara: RMSE = 1535.6474725665505, MAPE = 9.173670613033472%, R-Squared = -3.37409596173606
# Metrics for Kepulauan Bangka Belitung: RMSE = 2382.8375399572888, MAPE = 12.926385942557356%, R-Squared = -2.6077780884848245
# Metrics for Sulawesi Tengah: RMSE = 2234.4625151095584, MAPE = 12.337722115945889%, R-Squared = -2.278201145931463
# Metrics for Papua Barat: RMSE = 1567.2339065691506, MAPE = 7.914011364145074%, R-Squared = -2.141513204573826
# Metrics for D.I Yogyakarta: RMSE = 1268.2698490463383, MAPE = 7.27211062906573%, R-Squared = -5.328834349042666

# %%
# Contoh penggunaan untuk menampilkan metrik evaluasi provinsi tertentu
provinsi_to_check = 'Kalimantan Barat'
if provinsi_to_check in metrics_rf_dict:
    metrics = metrics_rf_dict[provinsi_to_check]
    print(f"Metrics for {provinsi_to_check}: RMSE = {metrics['RMSE']}, MAPE = %{metrics['MAPE']}, R-Squared = {metrics['R-Squared']}")
else:
    print(f"No metrics found for {provinsi_to_check}.")
# Out:
# Metrics for Kalimantan Barat: RMSE = 2022.1800097526932, MAPE = %10.908715979631598, R-Squared = -3.4401067190144374

# %%
# Fungsi untuk menampilkan hasil prediksi dan nilai sebenarnya
def plot_predictions(provinsi):
    if provinsi in metrics_rf_dict:
        y_true = metrics_rf_dict[provinsi]['y_true']
        y_pred = metrics_rf_dict[provinsi]['y_pred']
        
        plt.figure(figsize=(10, 6))
        plt.plot(y_true, label='Actual')
        plt.plot(y_pred, label='Predicted')
        plt.title(f"Actual vs Predicted Prices for {provinsi}")
        plt.xlabel("Time")
        plt.ylabel("Price")
        plt.legend()
        plt.show()
    else:
        print(f"No results found for {provinsi}.")

# %%
# Contoh penggunaan untuk menampilkan prediksi dan nilai sebenarnya provinsi tertentu
provinsi_to_check = 'Bali'
plot_predictions(provinsi_to_check)

# %%
# Gabungkan semua hasil prediksi dan nilai sebenarnya ke dalam satu DataFrame dengan tanggal
results_rf = []
for provinsi in metrics_rf_dict:
    y_true = metrics_rf_dict[provinsi]['y_true']
    y_pred = metrics_rf_dict[provinsi]['y_pred']
    test_dates = df[df['Nama Provinsi'] == provinsi].iloc[-len(y_true):]['Tanggal'].values
    for i in range(len(y_true)):
        results_rf.append([provinsi, test_dates[i], i+1, y_true[i], y_pred[i]])

# %%
# Buat DataFrame dari hasil prediksi dan nilai sebenarnya
results_rf_df = pd.DataFrame(results_rf, columns=['Provinsi', 'Tanggal', 'Index', 'Harga Sebenarnya', 'Prediksi Harga'])

# %%
# Simpan DataFrame ke file Excel
output_file_rf = 'prediksi_harga_beras_rf_final.xlsx'
with pd.ExcelWriter(output_file_rf) as writer:
    results_rf_df.to_excel(writer, index=False, sheet_name='Prediksi vs Harga Sebenarnya RF')

print(f"Hasil prediksi dan nilai sebenarnya telah disimpan ke {output_file_rf}.")
# Out:
# Hasil prediksi dan nilai sebenarnya telah disimpan ke prediksi_harga_beras_rf_final.xlsx.

# %%
# Fungsi untuk melakukan prediksi 12 bulan ke depan
def predict_future(provinsi, model, scaler, start_date, periods=12):
    # Ambil data terakhir untuk membuat prediksi
    provinsi_data = df[df['Nama Provinsi'] == provinsi]['Harga_scaled'].values
    last_sequence = provinsi_data[-seq_length:]
    
    # Simpan hasil prediksi
    predictions = []
    current_sequence = last_sequence.reshape(1, -1)
    
    for i in range(periods):
        # Prediksi bulan berikutnya
        next_pred = model.predict(current_sequence)
        
        # Simpan hasil prediksi
        predictions.append(next_pred[0])
        
        # Perbarui urutan data dengan menambahkan prediksi baru
        current_sequence = np.append(current_sequence[:, 1:], next_pred)
        current_sequence = current_sequence.reshape(1, -1)
    
    # Balikkan skala hasil prediksi
    predictions = scaler.inverse_transform(np.array(predictions).reshape(-1, 1)).flatten()
    
    # Buat daftar tanggal untuk 12 bulan ke depan
    dates = pd.date_range(start=start_date, periods=periods, freq='MS')
    
    return dates, predictions

# %%
# Dictionary untuk menyimpan hasil prediksi tiap provinsi
future_predictions = {}

# %%
# Mulai prediksi dari April 2023
start_date = '2023-04-01'

# %%
# Loop untuk melakukan prediksi 12 bulan ke depan tiap provinsi
for provinsi in models_rf:
    model_rf = models_rf[provinsi]
    scaler_rf = scalers_rf[provinsi]
    dates, predictions = predict_future(provinsi, model_rf, scaler_rf, start_date)
    future_predictions[provinsi] = {'dates': dates, 'predictions': predictions}

print("Future predictions completed.")
# Out:
# Future predictions completed.

# %%
# Fungsi untuk menampilkan hasil prediksi 12 bulan ke depan
def plot_future_predictions(provinsi):
    if provinsi in future_predictions:
        dates = future_predictions[provinsi]['dates']
        predictions = future_predictions[provinsi]['predictions']
        
        plt.figure(figsize=(10, 6))
        plt.plot(dates, predictions, label='Future Predictions')
        plt.title(f"Future Predictions for {provinsi}")
        plt.xlabel("Date")
        plt.ylabel("Price")
        plt.legend()
        plt.show()
    else:
        print(f"No future predictions found for {provinsi}.")

# %%
# Contoh penggunaan untuk menampilkan prediksi 12 bulan ke depan provinsi tertentu
provinsi_to_check = 'Aceh'
plot_future_predictions(provinsi_to_check)

# %%
# Gabungkan semua hasil prediksi ke dalam satu DataFrame
results_future = []
for provinsi in future_predictions:
    dates = future_predictions[provinsi]['dates']
    predictions = future_predictions[provinsi]['predictions']
    for date, pred in zip(dates, predictions):
        results_future.append([provinsi, date, pred])

# %%
# Buat DataFrame dari hasil prediksi
results_future_df = pd.DataFrame(results_future, columns=['Provinsi', 'Tanggal', 'Prediksi Harga'])

# %%
# Simpan DataFrame ke file Excel
output_file_future = 'prediksi_harga_beras_12_bulan_rf_final.xlsx'
with pd.ExcelWriter(output_file_future) as writer:
    results_future_df.to_excel(writer, index=False, sheet_name='Prediksi 12 Bulan ke Depan RF')

print(f"Hasil prediksi 12 bulan ke depan telah disimpan ke {output_file_future}.")
# Out:
# Hasil prediksi 12 bulan ke depan telah disimpan ke prediksi_harga_beras_12_bulan_rf_final.xlsx.

# %%
for provinsi in df['Nama Provinsi'].unique():
    provinsi_data = df[df['Nama Provinsi'] == provinsi]['Harga'].values
    print(f'{provinsi} - Data Points: {len(provinsi_data)}')
# Out:
# Aceh - Data Points: 76
# Bali - Data Points: 76
# Banten - Data Points: 76
# Bengkulu - Data Points: 76
# DI Yogyakarta - Data Points: 60
# DKI Jakarta - Data Points: 76
# Gorontalo - Data Points: 76
# Jambi - Data Points: 76
# Jawa Barat - Data Points: 76
# Jawa Tengah - Data Points: 76
# Jawa Timur - Data Points: 76
# Kalimantan Barat - Data Points: 76
# Kalimantan Selatan - Data Points: 76
# Kalimantan Tengah - Data Points: 76
# Kalimantan Timur - Data Points: 76
# Kalimantan Utara - Data Points: 76
# Kepulauan Riau - Data Points: 76
# Lampung - Data Points: 76
# Maluku - Data Points: 76
# Maluku Utara - Data Points: 76
# Nusa Tenggara Barat - Data Points: 76
# Nusa Tenggara Timur - Data Points: 76
# Papua - Data Points: 76
# Riau - Data Points: 76
# Sulawesi Barat - Data Points: 76
# Sulawesi Selatan - Data Points: 76
# Sulawesi Tenggara - Data Points: 76
# Sulawesi Utara - Data Points: 76
# Sumatera Barat - Data Points: 76
# Sumatera Selatan - Data Points: 76
# Sumatera Utara - Data Points: 76
# Kepulauan Bangka Belitung - Data Points: 75
# Sulawesi Tengah - Data Points: 75
# Papua Barat - Data Points: 73
# D.I Yogyakarta - Data Points: 16

# %%
for provinsi in df['Nama Provinsi'].unique():
    provinsi_data = df[df['Nama Provinsi'] == provinsi]['Harga'].values
    print(f'{provinsi} - Mean: {np.mean(provinsi_data)}, Std: {np.std(provinsi_data)}, Min: {np.min(provinsi_data)}, Max: {np.max(provinsi_data)}')
# Out:
# Aceh - Mean: 12554.552631578947, Std: 762.6852560929023, Min: 11740, Max: 14620
# Bali - Mean: 12407.342105263158, Std: 1209.6203248674396, Min: 11392, Max: 16790
# Banten - Mean: 12014.315789473685, Std: 1184.9966379091359, Min: 10952, Max: 16710
# Bengkulu - Mean: 12517.78947368421, Std: 1078.881515320252, Min: 11457, Max: 16010
# DI Yogyakarta - Mean: 11711.233333333334, Std: 551.8019380981631, Min: 10984, Max: 13100
# DKI Jakarta - Mean: 12946.842105263158, Std: 1035.6628191980496, Min: 12000, Max: 17420
# Gorontalo - Mean: 12129.763157894737, Std: 1354.5475635061894, Min: 11073, Max: 17540
# Jambi - Mean: 12753.052631578947, Std: 944.2768730724006, Min: 11638, Max: 15580
# Jawa Barat - Mean: 12249.0, Std: 1053.070035657648, Min: 11420, Max: 16640
# Jawa Tengah - Mean: 12215.421052631578, Std: 1070.710330662951, Min: 11242, Max: 16260
# Jawa Timur - Mean: 12079.723684210527, Std: 1048.221759867687, Min: 11154, Max: 15850
# Kalimantan Barat - Mean: 14180.947368421053, Std: 1099.6738499106384, Min: 12000, Max: 17420
# Kalimantan Selatan - Mean: 14699.934210526315, Std: 1489.5470376093172, Min: 12000, Max: 18730
# Kalimantan Tengah - Mean: 14632.802631578947, Std: 1228.7097963625445, Min: 12000, Max: 17830
# Kalimantan Timur - Mean: 13702.78947368421, Std: 1298.5914465883236, Min: 12000, Max: 18110
# Kalimantan Utara - Mean: 14109.302631578947, Std: 2001.4203970636827, Min: 14, Max: 17660
# Kepulauan Riau - Mean: 14048.723684210527, Std: 837.3783902074537, Min: 12000, Max: 16220
# Lampung - Mean: 12151.394736842105, Std: 1039.403245781309, Min: 11002, Max: 16150
# Maluku - Mean: 14478.342105263158, Std: 1205.4757911148565, Min: 12000, Max: 17910
# Maluku Utara - Mean: 14328.092105263158, Std: 1276.3199687262015, Min: 12000, Max: 18190
# Nusa Tenggara Barat - Mean: 11749.802631578947, Std: 1440.5980850412977, Min: 10120, Max: 17120
# Nusa Tenggara Timur - Mean: 13027.592105263158, Std: 1204.0899618606006, Min: 11181, Max: 17280
# Papua - Mean: 14924.671052631578, Std: 1458.2421590480803, Min: 12000, Max: 18650
# Riau - Mean: 14205.46052631579, Std: 944.2398006192109, Min: 12000, Max: 16460
# Sulawesi Barat - Mean: 11916.921052631578, Std: 1142.3575088289303, Min: 10423, Max: 15860
# Sulawesi Selatan - Mean: 11746.5, Std: 1173.5071199299628, Min: 10769, Max: 15630
# Sulawesi Tenggara - Mean: 12207.263157894737, Std: 1160.12078963244, Min: 10814, Max: 16330
# Sulawesi Utara - Mean: 12503.026315789473, Std: 1067.6724928268304, Min: 11375, Max: 16420
# Sumatera Barat - Mean: 13799.592105263158, Std: 1428.5638277436794, Min: 12000, Max: 17390
# Sumatera Selatan - Mean: 12271.118421052632, Std: 908.3892767320173, Min: 11435, Max: 15240
# Sumatera Utara - Mean: 12827.276315789473, Std: 844.7771833087456, Min: 12000, Max: 15460
# Kepulauan Bangka Belitung - Mean: 13222.533333333333, Std: 1173.8782143911787, Min: 12000, Max: 17460
# Sulawesi Tengah - Mean: 12353.786666666667, Std: 1238.2579730501325, Min: 11162, Max: 17270
# Papua Barat - Mean: 14968.27397260274, Std: 1390.508453967631, Min: 12000, Max: 18170
# D.I Yogyakarta - Mean: 13731.875, Std: 1246.9523785514025, Min: 12490, Max: 16380
